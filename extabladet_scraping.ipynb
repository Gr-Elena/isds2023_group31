# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
import re
from tqdm import tqdm
import pandas as pd
import requests

headers = {
    'name': 'Elena Gritskevich',
    'email': 'hfb570@alumni.ku.dk',
    'message': "Student of Copenhagen University, doing 1 week research project on machine learning"
}

# %%
#create list of urls for scraping - news' categories pages
url0 = 'https://ekstrabladet.dk/nyheder/'
url1='https://ekstrabladet.dk/nyheder/samfund/'
url2='https://ekstrabladet.dk/krimi/'
url3='https://ekstrabladet.dk/penge/'
url4='https://ekstrabladet.dk/nyheder/politik/'
url5='https://ekstrabladet.dk/nyheder/politik/danskpolitik/'
url6='https://ekstrabladet.dk/nyheder/terror/'
url7='https://ekstrabladet.dk/nyheder/krigogkatastrofer/'
url8= 'https://ekstrabladet.dk/sport/'  #10 additional sub urls
#url81= 'https://ekstrabladet.dk/sport/fodbold/landsholdsfodbold/VM2022/'
url9= 'https://ekstrabladet.dk/nyheder/samfund/vejret/'
#url10= 'https://ekstrabladet.dk/underholdning/' #8 sub categories

url_num= ['url0', 'url1', 'url2', 'url3', 'url4', 'url5', 'url6', 'url7', 'url8', 'url9']
categories = ['Nyheder', 'Samfund', 'Krimi', 'Penge', 'Politik','Dansk politik', 'Terror', 'Krig & katastrofer', 'Sport', 'Vejret']
urls = ['https://ekstrabladet.dk/nyheder/' \
        ,'https://ekstrabladet.dk/nyheder/samfund/' \
        ,'https://ekstrabladet.dk/krimi/' \
        ,'https://ekstrabladet.dk/penge/' \
        ,'https://ekstrabladet.dk/nyheder/politik/'\
        ,'https://ekstrabladet.dk/nyheder/politik/danskpolitik/'\
        ,'https://ekstrabladet.dk/nyheder/terror/'\
        ,'https://ekstrabladet.dk/nyheder/krigogkatastrofer/'\
        ,'https://ekstrabladet.dk/sport/' \
        ,'https://ekstrabladet.dk/nyheder/samfund/vejret/' ]

data = {'url_num': url_num, 'categories': categories, 'urls': urls}
url_list = pd.DataFrame(data)
url_list.set_index('url_num', inplace=True)
url_list
# Out:
#                  categories                                               urls
# url_num
# url0                Nyheder                   https://ekstrabladet.dk/nyheder/
# url1                Samfund           https://ekstrabladet.dk/nyheder/samfund/
# url2                  Krimi                     https://ekstrabladet.dk/krimi/
# url3                  Penge                     https://ekstrabladet.dk/penge/
# url4                Politik           https://ekstrabladet.dk/nyheder/politik/
# url5          Dansk politik  https://ekstrabladet.dk/nyheder/politik/danskp...
# url6                 Terror            https://ekstrabladet.dk/nyheder/terror/
# url7     Krig & katastrofer  https://ekstrabladet.dk/nyheder/krigogkatastro...
# url8                  Sport                     https://ekstrabladet.dk/sport/
# url9                 Vejret    https://ekstrabladet.dk/nyheder/samfund/vejret/

# %%
#scrap all links to articles from category pages

art_urls= []

for link in tqdm(url_list['urls']):
    response= requests.get(link, headers=headers)
    soup = BeautifulSoup(response.content, 'lxml')
    time.sleep(1)
    
    # Find all <a> elements with class 'card-mode' and extract href attribute
    href_elements = soup.find_all('a', class_='card-mode')
    
    # Extract href attribute value from each <a> element and append to art_urls list
    for href_element in href_elements:
        href = href_element.get('href')
        if href:
            art_urls.append(href)

art_urls
# Out:
# 100%|██████████| 10/10 [00:14<00:00,  1.46s/it]
# ['/nyheder/politik/villys-nye-comeback-derfor-stiller-jeg-op/9900422',
#  '/nyheder/politik/danskpolitik/se-ellemanns-antistress-plan/9897132',
#  '/nyheder/samfund/nikitas-dom-det-absolut-vaerste-sted-at-bo-i-koebenhavn/9896826',
#  '/nyheder/politik/danskpolitik/ellemann-alene-i-verden/9900600',
#  '/krimi/saadan-blev-23-tons-hash-fragtet-fra-landsby-til-landsby/9896641',
#  '/nyheder/politik/danskpolitik/kaempeskandale-endte-som-fuser/9847290',
#  '/nyheder/politik/danskpolitik/konservativ-krise-papes-problemer-staar-i-koe/9896705',
#  '/nyheder/samfund/ledige-pladser-tjen-40.000-som-nyuddannet/9895539',
#  '/nyheder/politik/danskpolitik/engells-dom-svag-start/9894415',
#  '/nyheder/politik/danskpolitik/engell-alle-tabte-paa-lizette-sagen/9889779',
#  '/krimi/michael-draebt-af-stik-i-brystet-niece-husker-ham-som-et-godt-menneske/9888793',
#  '/krimi/svenske-narkobagmaend-mistaenkt-for-eksplosioner-i-fynsk-boligkvarterer/9883349',
# ...

# %%
art_links1= pd.DataFrame(art_urls)
art_links1['full_link'] = 'https://ekstrabladet.dk' + art_links1[0]
art_links1.drop(columns=[0], inplace=True)
art_links1
# Out:
#                                              full_link
# 0    https://ekstrabladet.dk/nyheder/politik/villys...
# 1    https://ekstrabladet.dk/nyheder/politik/danskp...
# 2    https://ekstrabladet.dk/nyheder/samfund/nikita...
# 3    https://ekstrabladet.dk/nyheder/politik/danskp...
# 4    https://ekstrabladet.dk/krimi/saadan-blev-23-t...
# ..                                                 ...
# 235  https://ekstrabladet.dk/nyheder/samfund/unders...
# 236  https://ekstrabladet.dk/nyheder/samfund/person...
# 237  https://ekstrabladet.dk/nyheder/samfund/dmi-so...
# 238  https://ekstrabladet.dk/nyheder/krigogkatastro...
# 239  https://ekstrabladet.dk/nyheder/samfund/claus-...
#
# [240 rows x 1 columns]

# %%
# scrap data about each article PLUS new urls from "Læs mere"
data = []

for link in tqdm(art_links1['full_link']):
    response= requests.get(link, headers=headers)
    soup = BeautifulSoup(response.content, 'lxml')
     
    try:
        title = soup.find(class_='art-title')
        title= title.text.strip()
    except AttributeError:
        title= None
    
    
    try:
        category = soup.find(class_='section-indicator flex flex-align--center margin-m--r')
        category= category.text.strip()
    except AttributeError:
        category= None
        
    try:
        body = soup.find(class_='article-bodytext')
        body= body.text.strip()
    except AttributeError:
        body= None

        
    try:
        time = soup.find('div', class_='toggle toggle-off').find('span', {'data-timestamp': True})
        time= time['data-timestamp']
    except AttributeError:
        time= None

    try:
        author = soup.find(class_='flex flex-wrap--wrap')
        author= author.text.strip()
    except AttributeError:
        author= None
                
    data.append({'link': link, 'title': title, 'category': category, 'body': body, 'time': time, 'author' : author})
    
data=pd.DataFrame(data)
# Out:
# 100%|██████████| 240/240 [01:18<00:00,  3.07it/s]

# %%
data
# Out:
#                                                   link  \
# 0    https://ekstrabladet.dk/nyheder/politik/villys...
# 1    https://ekstrabladet.dk/nyheder/politik/danskp...
# 2    https://ekstrabladet.dk/nyheder/samfund/nikita...
# 3    https://ekstrabladet.dk/nyheder/politik/danskp...
# 4    https://ekstrabladet.dk/krimi/saadan-blev-23-t...
# ..                                                 ...
# 235  https://ekstrabladet.dk/nyheder/samfund/unders...
# 236  https://ekstrabladet.dk/nyheder/samfund/person...
# 237  https://ekstrabladet.dk/nyheder/samfund/dmi-so...
# 238  https://ekstrabladet.dk/nyheder/krigogkatastro...
# 239  https://ekstrabladet.dk/nyheder/samfund/claus-...
#
#                                                  title            category  \
# 0           Villys nye comeback: Derfor stiller jeg op             Politik
# 1                         Se Ellemanns antistress-plan       Dansk politik
# 2    Nikitas dom: - Det absolut værste sted at bo i...             Samfund
# ...

# %%
# scrap new links from articles - round 1

links1= []

for link in tqdm(art_links1['full_link']):
    response= requests.get(link, headers=headers)
    soup = BeautifulSoup(response.content, 'lxml')

    
    hrefs=soup.find_all('div', class_='list-item  svelte-1yeespr')
    
    for i in hrefs:
        href= i.find('a').get('href')
        if href:
            links1.append(href)
links1
# Out:
# 100%|██████████| 240/240 [01:57<00:00,  2.04it/s]
# []

# %%
<div class="horizontal-scroll-items horizontal-scroll-items--gap flex position-relative" 
data-horizontallist="horizontallist"><a href="/nyheder/samfund/stort-drama-i-luften-aggressivt/9789065" 
class="list-item  svelte-1yeespr" data-breaking="false" 
style="--color--list: var(--color--nyheder);--fgcolor--list: var(--fgcolor--nyheder);">
<div class="horizontal-content svelte-nsxf63">  <div class="horizontal-text-wrapper svelte-nsxf63">
<div class="horizontal-text svelte-nsxf63"><div class="list-item-meta  svelte-upbafr">
<div class="list-item-meta-section svelte-upbafr"><span class="flex flex-justify--center flex-align--center">
<svg style="--icon-size: 13px;" class="icon-svg" viewBox="0 0 14 14"><use xlink:href="#tag"></use></svg> 
    <span class="padding-s--l">Samfund</span></span></div> <button 
    class="list-item-save-btn toggle-button svelte-1xmyz0o" aria-expanded="false">
    <div class="icon-svg toggle toggle-off"><svg style="--icon-size: 13px;" 
    class="icon-svg" viewBox="0 0 14 14"><use xlink:href="#bookmark"></use></svg></div> <span 
        class="margin-s--l toggle-off">Gem</span></button></div> <h2 
        class="list-item-title svelte-1qj70b list-item-title--truncated" 
        style="--max-lines: 3;">Stort drama i luften: Aggressivt!</h2></div></div></div> 
            </a><a href="/nyheder/krigogkatastrofer/ny-taktik-presser-putin-vil-udsulte-russerne/9888588" 
            class="list-item  svelte-1yeespr" data-breaking="false" 
            style="--color--list: var(--color--nyheder);--fgcolor--list: var(--fgcolor--nyheder);">
            <div class="horizontal-content svelte-nsxf63">  <div class="horizontal-text-wrapper svelte-nsxf63"><div 
            class="horizontal-text svelte-nsxf63"><div class="list-item-meta  svelte-upbafr"><div 
            class="list-item-meta-section svelte-upbafr"><span class="flex flex-justify--center flex-align--center">
            <svg style="--icon-size: 13px;" class="icon-svg" viewBox="0 0 14 14"><use xlink:href="#tag"></use></svg> <span 
                class="padding-s--l">Krig &amp; katastrofer</span></span></div> <button 
                class="list-item-save-btn toggle-button svelte-1xmyz0o" aria-expanded="false"><div 
                class="icon-svg toggle toggle-off"><svg style="--icon-size: 13px;" 
                class="icon-svg" viewBox="0 0 14 14"><use xlink:href="#bookmark"></use></svg></div> <span 
                    class="margin-s--l toggle-off">Gem</span></button></div> <h2 
                    class="list-item-title svelte-1qj70b list-item-title--truncated" 
                    style="--max-lines: 3;">Ny taktik presser Putin - vil udsulte russerne</h2></div></div></div> 
                    </a><a href="/nyheder/krigogkatastrofer/video-ukrainsk-drone-angreb-i-sortehavet/9888181" 
                    class="list-item  svelte-1yeespr" data-breaking="false" style="--color--list: var(--color--nyheder);--fgcolor--list: var(--fgcolor--nyheder);"><div class="horizontal-content svelte-nsxf63">  <div class="horizontal-text-wrapper svelte-nsxf63"><div class="horizontal-text svelte-nsxf63"><div class="list-item-meta  svelte-upbafr"><div class="list-item-meta-section svelte-upbafr"><span class="flex flex-justify--center flex-align--center"><svg style="--icon-size: 13px;" class="icon-svg" viewBox="0 0 14 14"><use xlink:href="#tag"></use></svg> <span class="padding-s--l">Krig &amp; katastrofer</span></span></div> <button class="list-item-save-btn toggle-button svelte-1xmyz0o" aria-expanded="false"><div class="icon-svg toggle toggle-off"><svg style="--icon-size: 13px;" class="icon-svg" viewBox="0 0 14 14"><use xlink:href="#bookmark"></use></svg></div> <span class="margin-s--l toggle-off">Gem</span></button></div> <h2 class="list-item-title svelte-1qj70b list-item-title--truncated" style="--max-lines: 3;">Video: Ukrainsk drone-angreb i Sortehavet</h2></div></div></div> </a><a href="/nyheder/rusland-beskylder-ukraine-for-endnu-et-fejlslagent-droneangreb/9901386" class="list-item  svelte-1yeespr" data-breaking="false" style="--color--list: var(--color--nyheder);--fgcolor--list: var(--fgcolor--nyheder);"><div class="horizontal-content svelte-nsxf63"> <div class="list-item-image-container svelte-1c6ro0z" style="--img-width: 100%; "><img alt="Rusland beskylder Ukraine for endnu et fejlslagent droneangreb" class="list-item-image svelte-1c6ro0z" data-src="https://img-cdn-p.ekstrabladet.dk/image/ekstrabladet/9901393/relationBig_300/?at=ec99600e993406417368dae4a4d17aed"></div> <div class="horizontal-text-wrapper svelte-nsxf63"><div class="horizontal-text svelte-nsxf63"><div class="list-item-meta  svelte-upbafr"><div class="list-item-meta-section svelte-upbafr"><span class="flex flex-justify--center flex-align--center"><svg style="--icon-size: 13px;" class="icon-svg" viewBox="0 0 14 14"><use xlink:href="#tag"></use></svg> <span class="padding-s--l">Nyheder</span></span></div> <button class="list-item-save-btn toggle-button svelte-1xmyz0o" aria-expanded="false"><div class="icon-svg toggle toggle-off"><svg style="--icon-size: 13px;" class="icon-svg" viewBox="0 0 14 14"><use xlink:href="#bookmark"></use></svg></div> <span class="margin-s--l toggle-off">Gem</span></button></div> <h2 class="list-item-title svelte-1qj70b list-item-title--truncated" style="--max-lines: 3;">Rusland beskylder Ukraine for endnu et fejlslagent droneangreb</h2></div></div></div> </a></div>

# %%
<a href="/nyheder/krigogkatastrofer/ny-taktik-presser-putin-vil-udsulte-russerne/9888588" 
class="list-item  svelte-1yeespr" data-breaking="false" 
style="--color--list: var(--color--nyheder);--fgcolor--list: var(--fgcolor--nyheder);">
<div class="horizontal-content svelte-nsxf63">  
<div class="horizontal-text-wrapper svelte-nsxf63">
<div class="horizontal-text svelte-nsxf63"><div 
class="list-item-meta  svelte-upbafr"><div class="list-item-meta-section svelte-upbafr"><span 
class="flex flex-justify--center flex-align--center"><svg style="--icon-size: 13px;" 
class="icon-svg" viewBox="0 0 14 14"><use xlink:href="#tag"></use></svg> <span 
    class="padding-s--l">Krig &amp; katastrofer</span></span></div> <button 
    class="list-item-save-btn toggle-button svelte-1xmyz0o" aria-expanded="false"><div 
    class="icon-svg toggle toggle-off"><svg style="--icon-size: 13px;" 
    class="icon-svg" viewBox="0 0 14 14"><use xlink:href="#bookmark"></use></svg></div> <span 
        class="margin-s--l toggle-off">Gem</span></button></div> <h2 
        class="list-item-title svelte-1qj70b list-item-title--truncated" 
        style="--max-lines: 3;">Ny taktik presser Putin - vil udsulte russerne</h2></div></div></div> </a>

# %%
links1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'lxml')

Headline = []
Category = []
Authors = []
Time = []
All_text = []
nummer=0

max_retries = 10
retries = 0

for i in tqdm(range(5)):
    retries = 0
    while retries < max_retries:
        try:
            one_column_lists = soup.find_all('ul', {'data-columns': '1'})[i]
            break
        except:
            retries = retries + 1
            time.sleep(1)
    
    if retries == max_retries:
        print(f"Max tries at: Number {nummer} and i: {i}")
    
#    for one_column_list in one_column_lists:
#       artikler = one_column_list.find_all(class_='tc_teaser')

        for artikel in artikler:
            nummer = nummer + 1
 
            Category.append(artikel.find('span', class_='padding-s--l').text) #category
            Headline.append(artikel.find('h2', class_='card-title  ff-primary') #title

            href = artikel.find('a', class_='tc_teaser__link').get('href') #if link else None

            text = []
            if href:
                driver.execute_script(f'window.open("{href}", "_blank");')
                driver.switch_to.window(driver.window_handles[-1])

                new_html = driver.page_source
                new_soup = BeautifulSoup(new_html, 'lxml')

                #Category.append(new_soup.find('div', class_='tc_page__label').find('a', class_='tc_label tc_label--color-nyheder').text)
                #Headline.append(new_soup.find('header', class_="tc_page__header").find('h1').text)

                Authors.append(new_soup.find('div', class_="tc_byline").find('strong').text)
                Time.append(new_soup.find('time', class_='tc_timestamp').get('datetime'))
                
                if new_soup.find('div', class_="tc_liveblog__body", attrs={'data-adobe-context':"article-body"}):
                    article_body_div = new_soup.find('div', class_="tc_liveblog__body", attrs={'data-adobe-context':"article-body"})
                else:
                    article_body_div = new_soup.find('div', class_='tc_page__body', attrs={'data-adobe-context': 'article-body'})
                
                if article_body_div:
                    rich_content_paragraphs = article_body_div.find_all('p')

                    for paragraph in rich_content_paragraphs:
                        text.append(paragraph.text)

                All_text.append(text)

                driver.close()
                driver.switch_to.window(driver.window_handles[0])
